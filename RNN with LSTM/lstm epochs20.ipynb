# %%
import numpy as np


import re
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense, Dropout, LSTM, Input, Embedding,GRU
from keras.models import Sequential

from keras.utils import np_utils,Sequence
from keras.layers.normalization import BatchNormalization
from keras.layers import Activation
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
import time,os

# %%
file = open("/content/drive/MyDrive/466data/en_tech_train.txt", "rb")
train_set = file.read().decode(encoding='utf-8')

# %%
processed_train_set = train_set.split("\n")

# %%
with open("/content/drive/MyDrive/parameters"+"/1.h5","w") as obj:
    obj.write("new")

# %%
train = True

# %%
def produce_training_xy(processed_train_set, maxlen):
    training_sentences = []
    for each_line in processed_train_set:       
        split_line = [i for i in each_line.split(" ") if i]
        length = len(split_line)
        if length >= maxlen: 
            for each_word_index in range(length-maxlen+1):
                seq = split_line[each_word_index:each_word_index+maxlen]
                line = " ".join(seq)
                training_sentences.append(line)  

    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(training_sentences)

    sequences = np.array(tokenizer.texts_to_sequences(training_sentences))

    vocab_size = len(tokenizer.word_index) + 1

    return sequences[:, :-1], to_categorical(sequences[:, -1], num_classes = vocab_size), vocab_size

# %%
def load_weights_to_model(vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch):
    name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(lstm_unit_num, dropout_rate, dense_unit_num,epoch,each_input_length)
    model = Sequential()
    model.add(Embedding(vocab_size, 256))
    model.add(LSTM(lstm_unit_num))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_unit_num, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    full_path = "/content/drive/MyDrive/parameters/"+name
    if os.path.isfile(full_path):
        model.load_weights(full_path)
    model.summary()
    model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
def get_vocab_size(processed_train_set,each_input_length):
    training_sentences = []
    for each_line in processed_train_set:       
        split_line = [i for i in each_line.split(" ") if i]
        length = len(split_line)
        if length >= each_input_length: 
            for each_word_index in range(length-each_input_length+1):
                seq = split_line[each_word_index:each_word_index+each_input_length]
                line = " ".join(seq)
                training_sentences.append(line)  
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(training_sentences)

    sequences = np.array(tokenizer.texts_to_sequences(training_sentences))

    return len(tokenizer.word_index) + 1, tokenizer

def training_with_parameters(X, y, vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch):
    name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(lstm_unit_num, dropout_rate, dense_unit_num,epoch,each_input_length)
    

    # Define our language model:
    model = Sequential()
    model.add(Embedding(vocab_size, 256))
    model.add(LSTM(lstm_unit_num))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_unit_num, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    full_path = "/content/drive/MyDrive/parameters/"+name

    model.summary()
    model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    
    print("%s cache saved"%(name))
    checkpoint = ModelCheckpoint(name, 
                                monitor='loss', 
                                verbose=1,
                                save_best_only=True,
                                mode='min')
    callbacks_list = [checkpoint]
    model.fit(X,y, batch_size=256, epochs=epoch, callbacks=callbacks_list)
    
    model.save_weights(name)
    return model

# %%
# Hyperparameters that needs to be tuned.
if train:
    input_length = [5, 20]
    lstm_unit_num = [256, 512, 1024]
    dense_unit_num = [256]
    dropout_rate = [0.2]
    epochs = [20]
    model_collection = [] # A list of lists, each sub list has the form [model Object, input_length, lstm_unit_num, dropout_rate, dense_unit_num,epoche]
    for epo in epochs:
        for each_input_length in input_length:

            training_sentences = []
            for each_line in processed_train_set:       
                split_line = [i for i in each_line.split(" ") if i]
                length = len(split_line)
                if length >= each_input_length: 
                    for each_word_index in range(length-each_input_length+1):
                        seq = split_line[each_word_index:each_word_index+each_input_length]
                        line = " ".join(seq)
                        training_sentences.append(line)  

            tokenizer = Tokenizer()
            tokenizer.fit_on_texts(training_sentences)

            sequences = np.array(tokenizer.texts_to_sequences(training_sentences))

            vocab_size = len(tokenizer.word_index) + 1
            X,y = sequences[:, :-1], sequences[:, -1]
            y = to_categorical(y, num_classes = vocab_size)

            for each_lstm_unit_num in lstm_unit_num:
                for each_dense_unit_num in dense_unit_num:
                    for each_dropout_rate in dropout_rate:
                
                        #model = training_with_parameters(X, y, vocab_size, each_input_length, each_lstm_unit_num, each_dropout_rate, each_dense_unit_num, epo)
                        name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(each_lstm_unit_num, each_dropout_rate, each_dense_unit_num,epo,each_input_length)
    

                        # Define our language model:
                        model = Sequential()
                        model.add(Embedding(vocab_size, 256))
                        model.add(LSTM(each_lstm_unit_num))
                        model.add(Dropout(each_dropout_rate))
                        model.add(Dense(each_dense_unit_num, activation='relu'))
                        model.add(Dense(vocab_size, activation='softmax'))
                        full_path = "/content/drive/MyDrive/parameters/"+name
                        if os.path.isfile(full_path):
                            model.load_weights(full_path)
                        model.summary()
                        model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

                        
                        print("%s cache saved"%(full_path))
                        checkpoint = ModelCheckpoint(full_path, 
                                                    monitor='loss', 
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')
                        callbacks_list = [checkpoint]
                        model.fit(X,y, batch_size=256, epochs=epo, callbacks=callbacks_list)
                        
                        model.save_weights(full_path)
                        model_collection.append([model, each_input_length, each_lstm_unit_num, each_dropout_rate, each_dense_unit_num, epo])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 256)         5668352
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               65792
# _________________________________________________________________
# dense_1 (Dense)              (None, 22142)             5690494
# =================================================================
# Total params: 11,949,950
# Trainable params: 11,949,950
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5 cache saved
# Epoch 1/20
# 849/849 [==============================] - 42s 44ms/step - loss: 7.8429 - accuracy: 0.0565
#
# Epoch 00001: loss improved from inf to 7.46862, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 2/20
# 849/849 [==============================] - 38s 45ms/step - loss: 6.8824 - accuracy: 0.0975
#
# Epoch 00002: loss improved from 7.46862 to 6.79608, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 3/20
# 849/849 [==============================] - 38s 44ms/step - loss: 6.3152 - accuracy: 0.1319
#
# Epoch 00003: loss improved from 6.79608 to 6.27700, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 4/20
# 849/849 [==============================] - 36s 43ms/step - loss: 5.8340 - accuracy: 0.1553
#
# Epoch 00004: loss improved from 6.27700 to 5.81810, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 5/20
# 849/849 [==============================] - 36s 43ms/step - loss: 5.3977 - accuracy: 0.1774
#
# Epoch 00005: loss improved from 5.81810 to 5.39760, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 6/20
# 849/849 [==============================] - 36s 43ms/step - loss: 4.9549 - accuracy: 0.2012
#
# Epoch 00006: loss improved from 5.39760 to 4.97477, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 7/20
# 849/849 [==============================] - 36s 42ms/step - loss: 4.5043 - accuracy: 0.2302
#
# Epoch 00007: loss improved from 4.97477 to 4.53118, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 8/20
# 849/849 [==============================] - 36s 42ms/step - loss: 4.0241 - accuracy: 0.2728
#
# Epoch 00008: loss improved from 4.53118 to 4.08500, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 9/20
# 849/849 [==============================] - 36s 43ms/step - loss: 3.6053 - accuracy: 0.3194
#
# Epoch 00009: loss improved from 4.08500 to 3.66948, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 10/20
# 849/849 [==============================] - 36s 43ms/step - loss: 3.2361 - accuracy: 0.3703
#
# Epoch 00010: loss improved from 3.66948 to 3.30129, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 11/20
# 849/849 [==============================] - 36s 43ms/step - loss: 2.9232 - accuracy: 0.4167
#
# Epoch 00011: loss improved from 3.30129 to 2.99672, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 12/20
# 849/849 [==============================] - 36s 43ms/step - loss: 2.6588 - accuracy: 0.4566
#
# Epoch 00012: loss improved from 2.99672 to 2.74034, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 13/20
# 849/849 [==============================] - 37s 43ms/step - loss: 2.4438 - accuracy: 0.4908
#
# Epoch 00013: loss improved from 2.74034 to 2.52493, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 14/20
# 849/849 [==============================] - 36s 43ms/step - loss: 2.2610 - accuracy: 0.5196
#
# Epoch 00014: loss improved from 2.52493 to 2.34336, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 15/20
# 849/849 [==============================] - 36s 42ms/step - loss: 2.0902 - accuracy: 0.5491
#
# Epoch 00015: loss improved from 2.34336 to 2.17899, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 16/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.9632 - accuracy: 0.5697
#
# Epoch 00016: loss improved from 2.17899 to 2.04328, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 17/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.8361 - accuracy: 0.5911
#
# Epoch 00017: loss improved from 2.04328 to 1.91637, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 18/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.7204 - accuracy: 0.6127
#
# Epoch 00018: loss improved from 1.91637 to 1.80606, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 19/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.6102 - accuracy: 0.6328
#
# Epoch 00019: loss improved from 1.80606 to 1.70098, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Epoch 20/20
# 849/849 [==============================] - 35s 42ms/step - loss: 1.5285 - accuracy: 0.6468
#
# Epoch 00020: loss improved from 1.70098 to 1.61548, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_5.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 256)         5668352
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 512)               1574912
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 22142)             5690494
# =================================================================
# Total params: 13,065,086
# Trainable params: 13,065,086
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5 cache saved
# Epoch 1/20
# 849/849 [==============================] - 37s 42ms/step - loss: 1.7879 - accuracy: 0.5995
#
# Epoch 00001: loss improved from inf to 1.91813, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 2/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.5363 - accuracy: 0.6510
#
# Epoch 00002: loss improved from 1.91813 to 1.62457, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 3/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.3916 - accuracy: 0.6769
#
# Epoch 00003: loss improved from 1.62457 to 1.48151, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 4/20
# 849/849 [==============================] - 36s 42ms/step - loss: 1.2825 - accuracy: 0.6962
#
# Epoch 00004: loss improved from 1.48151 to 1.36014, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 5/20
# 849/849 [==============================] - 37s 43ms/step - loss: 1.1714 - accuracy: 0.7189
#
# Epoch 00005: loss improved from 1.36014 to 1.24807, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 6/20
# 849/849 [==============================] - 36s 43ms/step - loss: 1.0778 - accuracy: 0.7361
#
# Epoch 00006: loss improved from 1.24807 to 1.14977, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 7/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.9963 - accuracy: 0.7535
#
# Epoch 00007: loss improved from 1.14977 to 1.06314, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 8/20
# 849/849 [==============================] - 36s 43ms/step - loss: 0.9068 - accuracy: 0.7723
#
# Epoch 00008: loss improved from 1.06314 to 0.98689, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 9/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.8463 - accuracy: 0.7864
#
# Epoch 00009: loss improved from 0.98689 to 0.91378, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 10/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.7904 - accuracy: 0.7965
#
# Epoch 00010: loss improved from 0.91378 to 0.85355, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 11/20
# 849/849 [==============================] - 36s 43ms/step - loss: 0.7403 - accuracy: 0.8073
#
# Epoch 00011: loss improved from 0.85355 to 0.79907, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 12/20
# 849/849 [==============================] - 37s 44ms/step - loss: 0.6829 - accuracy: 0.8194
#
# Epoch 00012: loss improved from 0.79907 to 0.74175, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 13/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.6453 - accuracy: 0.8282
#
# Epoch 00013: loss improved from 0.74175 to 0.70101, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 14/20
# 849/849 [==============================] - 37s 44ms/step - loss: 0.6047 - accuracy: 0.8378
#
# Epoch 00014: loss improved from 0.70101 to 0.65806, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 15/20
# 849/849 [==============================] - 38s 44ms/step - loss: 0.5697 - accuracy: 0.8458
#
# Epoch 00015: loss improved from 0.65806 to 0.61861, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 16/20
# 849/849 [==============================] - 37s 44ms/step - loss: 0.5352 - accuracy: 0.8541
#
# Epoch 00016: loss improved from 0.61861 to 0.59141, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 17/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.5084 - accuracy: 0.8610
#
# Epoch 00017: loss improved from 0.59141 to 0.55598, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 18/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.4791 - accuracy: 0.8667
#
# Epoch 00018: loss improved from 0.55598 to 0.52759, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 19/20
# 849/849 [==============================] - 37s 44ms/step - loss: 0.4572 - accuracy: 0.8730
#
# Epoch 00019: loss improved from 0.52759 to 0.50538, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Epoch 20/20
# 849/849 [==============================] - 37s 43ms/step - loss: 0.4386 - accuracy: 0.8766
#
# Epoch 00020: loss improved from 0.50538 to 0.48116, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_5.h5
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 256)         5668352
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1024)              5246976
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_5 (Dense)              (None, 22142)             5690494
# =================================================================
# Total params: 16,868,222
# Trainable params: 16,868,222
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5 cache saved
# Epoch 1/20
# 849/849 [==============================] - 42s 48ms/step - loss: 7.7527 - accuracy: 0.0557
#
# Epoch 00001: loss improved from inf to 7.41570, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 2/20
# 849/849 [==============================] - 40s 47ms/step - loss: 6.8088 - accuracy: 0.1042
#
# Epoch 00002: loss improved from 7.41570 to 6.73011, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 3/20
# 849/849 [==============================] - 40s 47ms/step - loss: 6.2153 - accuracy: 0.1335
#
# Epoch 00003: loss improved from 6.73011 to 6.17786, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 4/20
# 849/849 [==============================] - 40s 47ms/step - loss: 5.7261 - accuracy: 0.1585
#
# Epoch 00004: loss improved from 6.17786 to 5.71107, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 5/20
# 849/849 [==============================] - 41s 48ms/step - loss: 5.2533 - accuracy: 0.1848
#
# Epoch 00005: loss improved from 5.71107 to 5.25833, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 6/20
# 849/849 [==============================] - 41s 48ms/step - loss: 4.7510 - accuracy: 0.2184
#
# Epoch 00006: loss improved from 5.25833 to 4.77356, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 7/20
# 849/849 [==============================] - 41s 48ms/step - loss: 4.2070 - accuracy: 0.2612
#
# Epoch 00007: loss improved from 4.77356 to 4.24950, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 8/20
# 849/849 [==============================] - 41s 48ms/step - loss: 3.6633 - accuracy: 0.3179
#
# Epoch 00008: loss improved from 4.24950 to 3.71052, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 9/20
# 849/849 [==============================] - 41s 48ms/step - loss: 3.1194 - accuracy: 0.3900
#
# Epoch 00009: loss improved from 3.71052 to 3.19638, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 10/20
# 849/849 [==============================] - 41s 48ms/step - loss: 2.6523 - accuracy: 0.4610
#
# Epoch 00010: loss improved from 3.19638 to 2.73525, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 11/20
# 849/849 [==============================] - 40s 48ms/step - loss: 2.2537 - accuracy: 0.5246
#
# Epoch 00011: loss improved from 2.73525 to 2.34363, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 12/20
# 849/849 [==============================] - 40s 48ms/step - loss: 1.9212 - accuracy: 0.5834
#
# Epoch 00012: loss improved from 2.34363 to 2.00688, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 13/20
# 849/849 [==============================] - 41s 48ms/step - loss: 1.6458 - accuracy: 0.6322
#
# Epoch 00013: loss improved from 2.00688 to 1.72606, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 14/20
# 849/849 [==============================] - 40s 47ms/step - loss: 1.3945 - accuracy: 0.6806
#
# Epoch 00014: loss improved from 1.72606 to 1.48525, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 15/20
# 849/849 [==============================] - 40s 47ms/step - loss: 1.2086 - accuracy: 0.7144
#
# Epoch 00015: loss improved from 1.48525 to 1.28137, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 16/20
# 849/849 [==============================] - 41s 48ms/step - loss: 1.0345 - accuracy: 0.7508
#
# Epoch 00016: loss improved from 1.28137 to 1.11177, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 17/20
# 849/849 [==============================] - 41s 48ms/step - loss: 0.8840 - accuracy: 0.7823
#
# Epoch 00017: loss improved from 1.11177 to 0.96034, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 18/20
# 849/849 [==============================] - 40s 47ms/step - loss: 0.7755 - accuracy: 0.8050
#
# Epoch 00018: loss improved from 0.96034 to 0.84506, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 19/20
# 849/849 [==============================] - 40s 48ms/step - loss: 0.6774 - accuracy: 0.8276
#
# Epoch 00019: loss improved from 0.84506 to 0.74254, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Epoch 20/20
# 849/849 [==============================] - 40s 47ms/step - loss: 0.5984 - accuracy: 0.8448
#
# Epoch 00020: loss improved from 0.74254 to 0.66071, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_5.h5
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 18188)             4674316
# =================================================================
# Total params: 9,921,548
# Trainable params: 9,921,548
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5 cache saved
# Epoch 1/20
# 235/235 [==============================] - 13s 44ms/step - loss: 8.1858 - accuracy: 0.0499
#
# Epoch 00001: loss improved from inf to 7.77450, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 2/20
# 235/235 [==============================] - 10s 43ms/step - loss: 7.2416 - accuracy: 0.0571
#
# Epoch 00002: loss improved from 7.77450 to 7.22754, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 3/20
# 235/235 [==============================] - 10s 44ms/step - loss: 6.9554 - accuracy: 0.0760
#
# Epoch 00003: loss improved from 7.22754 to 6.97197, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 4/20
# 235/235 [==============================] - 10s 44ms/step - loss: 6.7368 - accuracy: 0.0898
#
# Epoch 00004: loss improved from 6.97197 to 6.73602, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 5/20
# 235/235 [==============================] - 10s 44ms/step - loss: 6.5208 - accuracy: 0.1006
#
# Epoch 00005: loss improved from 6.73602 to 6.54194, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 6/20
# 235/235 [==============================] - 10s 43ms/step - loss: 6.3366 - accuracy: 0.1096
#
# Epoch 00006: loss improved from 6.54194 to 6.36402, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 7/20
# 235/235 [==============================] - 10s 43ms/step - loss: 6.1477 - accuracy: 0.1208
#
# Epoch 00007: loss improved from 6.36402 to 6.17904, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 8/20
# 235/235 [==============================] - 10s 44ms/step - loss: 5.9529 - accuracy: 0.1292
#
# Epoch 00008: loss improved from 6.17904 to 5.99060, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 9/20
# 235/235 [==============================] - 10s 44ms/step - loss: 5.7551 - accuracy: 0.1354
#
# Epoch 00009: loss improved from 5.99060 to 5.79485, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 10/20
# 235/235 [==============================] - 10s 43ms/step - loss: 5.5539 - accuracy: 0.1385
#
# Epoch 00010: loss improved from 5.79485 to 5.59117, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 11/20
# 235/235 [==============================] - 10s 43ms/step - loss: 5.3536 - accuracy: 0.1483
#
# Epoch 00011: loss improved from 5.59117 to 5.37342, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 12/20
# 235/235 [==============================] - 10s 43ms/step - loss: 5.0870 - accuracy: 0.1635
#
# Epoch 00012: loss improved from 5.37342 to 5.13717, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 13/20
# 235/235 [==============================] - 10s 43ms/step - loss: 4.8660 - accuracy: 0.1710
#
# Epoch 00013: loss improved from 5.13717 to 4.89648, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 14/20
# 235/235 [==============================] - 10s 43ms/step - loss: 4.5797 - accuracy: 0.1889
#
# Epoch 00014: loss improved from 4.89648 to 4.64116, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 15/20
# 235/235 [==============================] - 10s 43ms/step - loss: 4.3048 - accuracy: 0.2133
#
# Epoch 00015: loss improved from 4.64116 to 4.37983, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 16/20
# 235/235 [==============================] - 10s 42ms/step - loss: 4.0492 - accuracy: 0.2385
#
# Epoch 00016: loss improved from 4.37983 to 4.11466, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 17/20
# 235/235 [==============================] - 10s 42ms/step - loss: 3.7772 - accuracy: 0.2706
#
# Epoch 00017: loss improved from 4.11466 to 3.86229, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 18/20
# 235/235 [==============================] - 10s 42ms/step - loss: 3.5186 - accuracy: 0.3039
#
# Epoch 00018: loss improved from 3.86229 to 3.61127, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 19/20
# 235/235 [==============================] - 10s 42ms/step - loss: 3.2811 - accuracy: 0.3345
#
# Epoch 00019: loss improved from 3.61127 to 3.37903, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Epoch 20/20
# 235/235 [==============================] - 10s 42ms/step - loss: 3.0658 - accuracy: 0.3680
#
# Epoch 00020: loss improved from 3.37903 to 3.15177, saving model to /content/drive/MyDrive/parameters/rnn_weights_256_0.20_256_20_20.h5
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 512)               1574912
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_9 (Dense)              (None, 18188)             4674316
# =================================================================
# Total params: 11,036,684
# Trainable params: 11,036,684
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5 cache saved
# Epoch 1/20
# 235/235 [==============================] - 13s 48ms/step - loss: 8.1417 - accuracy: 0.0494
#
# Epoch 00001: loss improved from inf to 7.75709, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 2/20
# 235/235 [==============================] - 11s 49ms/step - loss: 7.1814 - accuracy: 0.0639
#
# Epoch 00002: loss improved from 7.75709 to 7.18593, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 3/20
# 235/235 [==============================] - 11s 48ms/step - loss: 6.9173 - accuracy: 0.0828
#
# Epoch 00003: loss improved from 7.18593 to 6.88653, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 4/20
# 235/235 [==============================] - 11s 48ms/step - loss: 6.6010 - accuracy: 0.1004
#
# Epoch 00004: loss improved from 6.88653 to 6.64351, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 5/20
# 235/235 [==============================] - 11s 48ms/step - loss: 6.4030 - accuracy: 0.1087
#
# Epoch 00005: loss improved from 6.64351 to 6.43753, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 6/20
# 235/235 [==============================] - 11s 48ms/step - loss: 6.1951 - accuracy: 0.1228
#
# Epoch 00006: loss improved from 6.43753 to 6.22961, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 7/20
# 235/235 [==============================] - 11s 49ms/step - loss: 6.0279 - accuracy: 0.1284
#
# Epoch 00007: loss improved from 6.22961 to 6.04411, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 8/20
# 235/235 [==============================] - 11s 48ms/step - loss: 5.8111 - accuracy: 0.1385
#
# Epoch 00008: loss improved from 6.04411 to 5.86038, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 9/20
# 235/235 [==============================] - 11s 48ms/step - loss: 5.6141 - accuracy: 0.1440
#
# Epoch 00009: loss improved from 5.86038 to 5.66541, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 10/20
# 235/235 [==============================] - 11s 48ms/step - loss: 5.6132 - accuracy: 0.1386
#
# Epoch 00010: loss improved from 5.66541 to 5.55839, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 11/20
# 235/235 [==============================] - 11s 48ms/step - loss: 5.2286 - accuracy: 0.1541
#
# Epoch 00011: loss improved from 5.55839 to 5.29207, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 12/20
# 235/235 [==============================] - 11s 48ms/step - loss: 5.0235 - accuracy: 0.1624
#
# Epoch 00012: loss improved from 5.29207 to 5.07561, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 13/20
# 235/235 [==============================] - 11s 48ms/step - loss: 4.7818 - accuracy: 0.1797
#
# Epoch 00013: loss improved from 5.07561 to 4.85074, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 14/20
# 235/235 [==============================] - 11s 48ms/step - loss: 4.5542 - accuracy: 0.1943
#
# Epoch 00014: loss improved from 4.85074 to 4.62249, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 15/20
# 235/235 [==============================] - 11s 48ms/step - loss: 4.4025 - accuracy: 0.2129
#
# Epoch 00015: loss improved from 4.62249 to 4.44630, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 16/20
# 235/235 [==============================] - 11s 48ms/step - loss: 4.1468 - accuracy: 0.2335
#
# Epoch 00016: loss improved from 4.44630 to 4.21204, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 17/20
# 235/235 [==============================] - 11s 48ms/step - loss: 3.9070 - accuracy: 0.2586
#
# Epoch 00017: loss improved from 4.21204 to 4.00378, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 18/20
# 235/235 [==============================] - 11s 47ms/step - loss: 3.7091 - accuracy: 0.2822
#
# Epoch 00018: loss improved from 4.00378 to 3.81595, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 19/20
# 235/235 [==============================] - 11s 47ms/step - loss: 3.5657 - accuracy: 0.2996
#
# Epoch 00019: loss improved from 3.81595 to 3.63372, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Epoch 20/20
# 235/235 [==============================] - 11s 47ms/step - loss: 3.3963 - accuracy: 0.3249
#
# Epoch 00020: loss improved from 3.63372 to 3.46506, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_20_20.h5
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 1024)              5246976
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_11 (Dense)             (None, 18188)             4674316
# =================================================================
# Total params: 14,839,820
# Trainable params: 14,839,820
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5 cache saved
# Epoch 1/20
# 235/235 [==============================] - 16s 64ms/step - loss: 8.1117 - accuracy: 0.0453
#
# Epoch 00001: loss improved from inf to 7.73625, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 2/20
# 235/235 [==============================] - 15s 63ms/step - loss: 7.2258 - accuracy: 0.0607
#
# Epoch 00002: loss improved from 7.73625 to 7.21449, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 3/20
# 235/235 [==============================] - 15s 64ms/step - loss: 6.9533 - accuracy: 0.0812
#
# Epoch 00003: loss improved from 7.21449 to 6.95259, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 4/20
# 235/235 [==============================] - 15s 64ms/step - loss: 6.6910 - accuracy: 0.0936
#
# Epoch 00004: loss improved from 6.95259 to 6.71052, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 5/20
# 235/235 [==============================] - 15s 64ms/step - loss: 6.4807 - accuracy: 0.1048
#
# Epoch 00005: loss improved from 6.71052 to 6.48750, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 6/20
# 235/235 [==============================] - 15s 64ms/step - loss: 6.2170 - accuracy: 0.1191
#
# Epoch 00006: loss improved from 6.48750 to 6.25551, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 7/20
# 235/235 [==============================] - 15s 64ms/step - loss: 6.0016 - accuracy: 0.1283
#
# Epoch 00007: loss improved from 6.25551 to 6.03341, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 8/20
# 235/235 [==============================] - 15s 64ms/step - loss: 5.7505 - accuracy: 0.1359
#
# Epoch 00008: loss improved from 6.03341 to 5.79999, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 9/20
# 235/235 [==============================] - 15s 64ms/step - loss: 5.4958 - accuracy: 0.1463
#
# Epoch 00009: loss improved from 5.79999 to 5.55107, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 10/20
# 235/235 [==============================] - 15s 64ms/step - loss: 5.2205 - accuracy: 0.1544
#
# Epoch 00010: loss improved from 5.55107 to 5.27806, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 11/20
# 235/235 [==============================] - 15s 64ms/step - loss: 4.9172 - accuracy: 0.1703
#
# Epoch 00011: loss improved from 5.27806 to 4.99395, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 12/20
# 235/235 [==============================] - 15s 64ms/step - loss: 4.6863 - accuracy: 0.1840
#
# Epoch 00012: loss improved from 4.99395 to 4.74871, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 13/20
# 235/235 [==============================] - 15s 64ms/step - loss: 4.3738 - accuracy: 0.2097
#
# Epoch 00013: loss improved from 4.74871 to 4.45191, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 14/20
# 235/235 [==============================] - 15s 63ms/step - loss: 4.0664 - accuracy: 0.2375
#
# Epoch 00014: loss improved from 4.45191 to 4.17741, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 15/20
# 235/235 [==============================] - 15s 64ms/step - loss: 3.8260 - accuracy: 0.2679
#
# Epoch 00015: loss improved from 4.17741 to 3.92659, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 16/20
# 235/235 [==============================] - 15s 63ms/step - loss: 3.5629 - accuracy: 0.3024
#
# Epoch 00016: loss improved from 3.92659 to 3.67376, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 17/20
# 235/235 [==============================] - 15s 63ms/step - loss: 3.3442 - accuracy: 0.3354
#
# Epoch 00017: loss improved from 3.67376 to 3.44270, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 18/20
# 235/235 [==============================] - 15s 64ms/step - loss: 3.1313 - accuracy: 0.3639
#
# Epoch 00018: loss improved from 3.44270 to 3.23071, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 19/20
# 235/235 [==============================] - 15s 64ms/step - loss: 2.9339 - accuracy: 0.3945
#
# Epoch 00019: loss improved from 3.23071 to 3.04041, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5
# Epoch 20/20
# 235/235 [==============================] - 15s 64ms/step - loss: 2.7594 - accuracy: 0.4245
#
# Epoch 00020: loss improved from 3.04041 to 2.86029, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_20_20.h5

# %%
# !python -m spacy download en_core_web_lg
# !pip3 install -U spacy
import spacy
from tensorflow.keras.preprocessing.sequence import pad_sequences
from spacy.lang.en.examples import sentences
# Out:
# 2021-04-05 19:50:26.052577: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8MB)
#      |████████████████████████████████| 778.8MB 21kB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.0.0) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.8.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.8.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.4.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.7.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.23.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.19.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.7.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (54.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (20.9)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.4.1)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.24.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.7)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Installing collected packages: en-core-web-lg
#   Found existing installation: en-core-web-lg 2.2.5
#     Uninstalling en-core-web-lg-2.2.5:
#       Successfully uninstalled en-core-web-lg-2.2.5
# Successfully installed en-core-web-lg-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Requirement already up-to-date: spacy in /usr/local/lib/python3.7/dist-packages (3.0.5)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied, skipping upgrade: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (54.2.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (20.9)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy) (3.8.1)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied, skipping upgrade: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied, skipping upgrade: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.3.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied, skipping upgrade: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.0)
# Requirement already satisfied, skipping upgrade: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied, skipping upgrade: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.7.3)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied, skipping upgrade: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: thinc<8.1.0,>=8.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.2)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (3.0.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy) (3.4.1)
# Requirement already satisfied, skipping upgrade: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)

# %%
nlp = spacy.load('en_core_web_lg')

# %%
file = open("/content/drive/MyDrive/466data/en_tech_test.txt", "rb")
test_set = file.read().decode(encoding='utf-8')
file = open("/content/drive/MyDrive/466data/en_tech_validate.txt", "rb")
validate_set = file.read().decode(encoding='utf-8')
processed_test_set = test_set.split("\n")
processed_validate_set = validate_set.split("\n")

# %%
def predict_single(model, tokenizer, seed_text,maxlength):
    
    predicted_word = None
    encoded = tokenizer.texts_to_sequences([seed_text])[0]
    encoded = pad_sequences([encoded], maxlen = maxlength-1, truncating='pre')

    temp = model.predict(encoded)

    y_predict = np.argmax(temp, axis=-1)

    for word, index in tokenizer.word_index.items():
        if index == y_predict:
            predicted_word = word
            break
    return str(predicted_word)

def validate(validate_sentences, nlp, model,tokenizer,input_size):
  new = []
  for i in range(len(validate_sentences)):
      new.append(validate_sentences[i].split())
  validate_sequences = np.array(new)
  validate_X, validate_y = validate_sequences[:, :-1], validate_sequences[:, -1]
  average_accuracy = 0
  num = 0
  for i in range(len(validate_X)):
      if i%200==0:
          print(i)
      prediction = predict_single(model, tokenizer, ' '.join(validate_X[i]),input_size)
      x = nlp(prediction)
      y = nlp(str(validate_y[i]))

      if (x[0].has_vector) and (y[0].has_vector):
          average_accuracy += nlp(prediction).similarity(nlp(str(validate_y[i])))
          num += 1

  average_accuracy /= num
  return average_accuracy

# %%
input_length = [5, 20]
lstm_unit_num = [256, 512, 1024]
dense_unit_num = 256
dropout_rate = 0.2
epoch = 20
model_list = []
tokenizer = None
for i in lstm_unit_num:
    for j in input_length:
        vocab_size,tokenizer = get_vocab_size(processed_train_set,j)  
        #vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch   
        model = load_weights_to_model(vocab_size, j, i, dropout_rate, dense_unit_num, epoch)
        

        # validation
        validate_sentences = []
        input_size = j
        for line in processed_validate_set:
            temp = line.split()
            for index in range(input_size, len(temp)):
                seq = temp[index - input_size:index]
                temp2 = " ".join(seq)
                validate_sentences.append(temp2)
        
        accuracy = validate(validate_sentences, nlp, model,tokenizer,j)
        print("LSTM %d, Input_length %d finished, accuracy %.3f"%(i,j,accuracy))
        model_list.append([model,vocab_size, j, i, dropout_rate, dense_unit_num, epoch, accuracy])
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_14 (Embedding)     (None, None, 256)         5668352
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 256)               525312
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_29 (Dense)             (None, 22142)             5690494
# =================================================================
# Total params: 11,949,950
# Trainable params: 11,949,950
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# LSTM 256, Input_length 5 finished, accuracy 0.486
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_15 (Embedding)     (None, None, 256)         4656128
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 256)               525312
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_31 (Dense)             (None, 18188)             4674316
# =================================================================
# Total params: 9,921,548
# Trainable params: 9,921,548
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# LSTM 256, Input_length 20 finished, accuracy 0.409
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_16 (Embedding)     (None, None, 256)         5668352
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 512)               1574912
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_33 (Dense)             (None, 22142)             5690494
# =================================================================
# Total params: 13,065,086
# Trainable params: 13,065,086
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# LSTM 512, Input_length 5 finished, accuracy 0.518
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_17 (Embedding)     (None, None, 256)         4656128
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 512)               1574912
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_35 (Dense)             (None, 18188)             4674316
# =================================================================
# Total params: 11,036,684
# Trainable params: 11,036,684
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# LSTM 512, Input_length 20 finished, accuracy 0.422
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_18 (Embedding)     (None, None, 256)         5668352
# _________________________________________________________________
# lstm_18 (LSTM)               (None, 1024)              5246976
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_37 (Dense)             (None, 22142)             5690494
# =================================================================
# Total params: 16,868,222
# Trainable params: 16,868,222
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# LSTM 1024, Input_length 5 finished, accuracy 0.514
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_19 (Embedding)     (None, None, 256)         4656128
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 1024)              5246976
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_38 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_39 (Dense)             (None, 18188)             4674316
# =================================================================
# Total params: 14,839,820
# Trainable params: 14,839,820
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# LSTM 1024, Input_length 20 finished, accuracy 0.418

# %%
max_value = 0
max_index = 0
for i in range(len(model_list)):
    if model_list[i][-1]>max_value:
        max_value = model_list[i][-1]
        max_index = model_list[i]

# %%
import matplotlib.pyplot as plt

# %%
#vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch   
for k in [256,512,1024]:
    temp_list = [(i[2],i[-1]) for i in model_list if i[3] == k]
    plt.plot([i[0] for i in temp_list],[i[1] for i in temp_list],'o-',label="LSTM unit=%d"%k)
    #plt.legend(str(k))
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.plot(max_index[2], max_index[-1], 'r*',markersize=10)

# %%
model = load_weights_to_model(22142, 5, 1024, dropout_rate, dense_unit_num, epoch)

#name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(each_lstm_unit_num, each_dropout_rate, each_dense_unit_num,epo,each_input_length)
accuracy_list = []
for input_size in [2,3,5,10,20]:
    test_sentences = []
    for line in processed_test_set:
        #print("line",line)
        temp = line.split(' ')
        #print("temp",temp)
        if input_size<=len(temp):
            for i in range(input_size, len(temp)):
                #print("i",i)
                #print("input_size",input_size)
                seq = temp[i - input_size:i]
                #print("sep",seq)
                temp2 = " ".join(seq)
                test_sentences.append(temp2)
                #print("test",test_sentences)
                #assert 1==2,'stop'
    #print(test_sentences[0:20])
    #print(len(test_sentences))
    new = []
    
    #print(len(test_sentences))
    for i in range(len(test_sentences)):
        if i%5==0:
            
            new.append(test_sentences[i].split())
    print("new",new[0:2])
    print(new[0][0])
    test_seq = new

    test_X, test_y = [i[0:-1] for i in test_seq], [i[-1] for i in test_seq]
    print(test_X[0:10])
    print(test_seq[:][1])
    average_accuracy = 0
    num = 0
    for i in range(len(test_X)):
        prediction = predict_single(model, tokenizer, ' '.join(test_X[i]),input_size)
        if i%200==0:
            print(i)
        x = nlp(prediction)
        y = nlp(str(test_y[i]))

        if (x[0].has_vector) and (y[0].has_vector):
            average_accuracy += nlp(prediction).similarity(nlp(str(test_y[i])))
            num += 1  
    average_accuracy /= num
    accuracy_list.append((input_size,average_accuracy))
print(accuracy_list)
# Out:
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_51 (Embedding)     (None, None, 256)         5668352
# _________________________________________________________________
# lstm_51 (LSTM)               (None, 1024)              5246976
# _________________________________________________________________
# dropout_51 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_102 (Dense)            (None, 256)               262400
# _________________________________________________________________
# dense_103 (Dense)            (None, 22142)             5690494
# =================================================================
# Total params: 16,868,222
# Trainable params: 16,868,222
# Non-trainable params: 0
# _________________________________________________________________
# new [['merle', 'kilgore'], ['country', 'hit']]
# merle
# [['merle'], ['country'], ['has'], ['failure'], ['a'], ['that'], ['money'], ['on'], ['nbc'], ['had']]
# ['country', 'hit']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# new [['merle', 'kilgore', 'cowriter'], ['country', 'hit', 'ring']]
# merle
# [['merle', 'kilgore'], ['country', 'hit'], ['has', 'died'], ['other', 'scam'], ['link', 'to'], ['supposedly', 'let'], ['but', 'instead'], ['their', 'computers'], ['that', 'boxing'], ['violated', 'but']]
# ['country', 'hit', 'ring']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# new [['merle', 'kilgore', 'cowriter', 'of', 'the'], ['country', 'hit', 'ring', 'of', 'fire']]
# merle
# [['merle', 'kilgore', 'cowriter', 'of'], ['country', 'hit', 'ring', 'of'], ['has', 'died', 'of', 'congestive'], ['emails', 'included', 'a', 'link'], ['a', 'website', 'that', 'supposedly'], ['people', 'donate', 'money', 'but'], ['loaded', 'spyware', 'on', 'their'], ['alleged', 'that', 'boxing', 'regulations'], ['been', 'violated', 'but', 'failed'], ['their', 'attempt', 'to', 'have']]
# ['country', 'hit', 'ring', 'of', 'fire']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# new [['merle', 'kilgore', 'cowriter', 'of', 'the', 'country', 'hit', 'ring', 'of', 'fire'], ['country', 'hit', 'ring', 'of', 'fire', 'has', 'died', 'of', 'congestive', 'heart']]
# merle
# [['merle', 'kilgore', 'cowriter', 'of', 'the', 'country', 'hit', 'ring', 'of'], ['country', 'hit', 'ring', 'of', 'fire', 'has', 'died', 'of', 'congestive'], ['emails', 'included', 'a', 'link', 'to', 'a', 'website', 'that', 'supposedly'], ['a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but'], ['people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their'], ['alleged', 'that', 'boxing', 'regulations', 'had', 'been', 'violated', 'but', 'failed'], ['been', 'violated', 'but', 'failed', 'in', 'their', 'attempt', 'to', 'have'], ['a', 'village', 'says', 'prof', 'reddy', 'i', 'know', 'what', 'the'], ['i', 'know', 'what', 'the', 'population', 'is', 'like', 'many', 'of'], ['is', 'like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many']]
# ['country', 'hit', 'ring', 'of', 'fire', 'has', 'died', 'of', 'congestive', 'heart']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# new [['other', 'scam', 'emails', 'included', 'a', 'link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on'], ['link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their', 'computers', 'that', 'grabbed', 'confidential']]
# other
# [['other', 'scam', 'emails', 'included', 'a', 'link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware'], ['link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their', 'computers', 'that', 'grabbed'], ['village', 'says', 'prof', 'reddy', 'i', 'know', 'what', 'the', 'population', 'is', 'like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many', 'of'], ['know', 'what', 'the', 'population', 'is', 'like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many', 'of', 'them', 'have', 'other', 'concerns', 'there'], ['like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many', 'of', 'them', 'have', 'other', 'concerns', 'there', 'nobody', 'will', 'use', 'it', 'for'], ['illiterate', 'and', 'many', 'of', 'them', 'have', 'other', 'concerns', 'there', 'nobody', 'will', 'use', 'it', 'for', 'the', 'conventional', 'uses', 'of', 'a'], ['have', 'other', 'concerns', 'there', 'nobody', 'will', 'use', 'it', 'for', 'the', 'conventional', 'uses', 'of', 'a', 'pc', 'word', 'processing', 'and', 'powerpoint'], ['in', 'a', 'statement', 'google', 'said', 'the', 'feature', 'was', 'still', 'only', 'in', 'beta', 'ie', 'trial', 'stage', 'and', 'that', 'the', 'company'], ['they', 'are', 'likely', 'to', 'have', 'higher', 'disposable', 'incomes', 'and', 'can', 'afford', 'the', 'price', 'of', 'bigscreen', 'highdefinition', 'display', 'technologies', 'and'], ['recent', 'years', 'she', 'appeared', 'in', 'bbc', 'miniseries', 'the', 'cazalets', 'and', 'played', 'mrs', 'potts', 'in', 'the', 'london', 'stage', 'version', 'of']]
# ['link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their', 'computers', 'that', 'grabbed', 'confidential']
# 0
# 200
# 400
# 600
# 800
# 1000
# [(2, 0.35303359963313097), (3, 0.36747657473411277), (5, 0.3149940382720342), (10, 0.3015222232546607), (20, 0.3172721330288149)]
# "\ndef validate(validate_sentences, nlp, model,tokenizer,input_size):\n  new = []\n  for i in range(len(validate_sentences)):\n      new.append(validate_sentences[i].split())\n  validate_sequences = np.array(new)\n  validate_X, validate_y = validate_sequences[:, :-1], validate_sequences[:, -1]\n  average_accuracy = 0\n  num = 0\n  for i in range(len(validate_X)):\n      if i%200==0:\n          print(i)\n      prediction = predict_single(model, tokenizer, ' '.join(validate_X[i]),input_size)\n      x = nlp(prediction)\n      y = nlp(str(validate_y[i]))\n\n      if (x[0].has_vector) and (y[0].has_vector):\n          average_accuracy += nlp(prediction).similarity(nlp(str(validate_y[i])))\n          num += 1\n\n  average_accuracy /= num\n  return average_accuracy\n\n\n"

# %%
x = [i[0]-1 for i in accuracy_list]
y = [i[1] for i in accuracy_list]
plt.plot(x,y,'o-')
plt.title("RNN-LSTM with epoch=20")
plt.xlabel("test sentense word length")
plt.ylabel("average similarity")
# Out:
# Text(0, 0.5, 'average similarity')
