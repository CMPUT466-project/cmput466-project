# %%
import numpy as np


import re
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense, Dropout, LSTM, Input, Embedding,GRU
from keras.models import Sequential

from keras.utils import np_utils,Sequence
from keras.layers.normalization import BatchNormalization
from keras.layers import Activation
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import to_categorical
import time,os

# %%
file = open("/content/drive/MyDrive/466data/en_tech_train.txt", "rb")
train_set = file.read().decode(encoding='utf-8')

# %%
processed_train_set = train_set.split("\n")

# %%
with open("/content/drive/MyDrive/parameters"+"/1.h5","w") as obj:
    obj.write("new")

# %%
train = True

# %%
def produce_training_xy(processed_train_set, maxlen):
    training_sentences = []
    for each_line in processed_train_set:       
        split_line = [i for i in each_line.split(" ") if i]
        length = len(split_line)
        if length >= maxlen: 
            for each_word_index in range(length-maxlen+1):
                seq = split_line[each_word_index:each_word_index+maxlen]
                line = " ".join(seq)
                training_sentences.append(line)  

    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(training_sentences)

    sequences = np.array(tokenizer.texts_to_sequences(training_sentences))

    vocab_size = len(tokenizer.word_index) + 1

    return sequences[:, :-1], to_categorical(sequences[:, -1], num_classes = vocab_size), vocab_size

# %%
def load_weights_to_model(vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch):
    name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(lstm_unit_num, dropout_rate, dense_unit_num,epoch,each_input_length)
    model = Sequential()
    model.add(Embedding(vocab_size, 256))
    model.add(LSTM(lstm_unit_num))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_unit_num, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    full_path = "/content/drive/MyDrive/parameters/"+name
    if os.path.isfile(full_path):
        model.load_weights(full_path)
    model.summary()
    model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
def get_vocab_size(processed_train_set,each_input_length):
    training_sentences = []
    for each_line in processed_train_set:       
        split_line = [i for i in each_line.split(" ") if i]
        length = len(split_line)
        if length >= each_input_length: 
            for each_word_index in range(length-each_input_length+1):
                seq = split_line[each_word_index:each_word_index+each_input_length]
                line = " ".join(seq)
                training_sentences.append(line)  
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(training_sentences)

    sequences = np.array(tokenizer.texts_to_sequences(training_sentences))

    return len(tokenizer.word_index) + 1, tokenizer

def training_with_parameters(X, y, vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch):
    name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(lstm_unit_num, dropout_rate, dense_unit_num,epoch,each_input_length)
    

    # Define our language model:
    model = Sequential()
    model.add(Embedding(vocab_size, 256))
    model.add(LSTM(lstm_unit_num))
    model.add(Dropout(dropout_rate))
    model.add(Dense(dense_unit_num, activation='relu'))
    model.add(Dense(vocab_size, activation='softmax'))
    full_path = "/content/drive/MyDrive/parameters/"+name
    if os.path.isfile(full_path):
        model.load_weights(full_path)
    model.summary()
    model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    
    print("%s cache saved"%(name))
    checkpoint = ModelCheckpoint(name, 
                                monitor='loss', 
                                verbose=1,
                                save_best_only=True,
                                mode='min')
    callbacks_list = [checkpoint]
    model.fit(X,y, batch_size=256, epochs=epoch, callbacks=callbacks_list)
    
    model.save_weights(name)
    return model

# %%
# Hyperparameters that needs to be tuned.
if train:
    input_length = [20]
    lstm_unit_num = [512, 1024]
    dense_unit_num = [256]
    dropout_rate = [0.2]
    epochs = [30]
    model_collection = [] # A list of lists, each sub list has the form [model Object, input_length, lstm_unit_num, dropout_rate, dense_unit_num,epoche]
    for epo in epochs:
        for each_input_length in input_length:

            training_sentences = []
            for each_line in processed_train_set:       
                split_line = [i for i in each_line.split(" ") if i]
                length = len(split_line)
                if length >= each_input_length: 
                    for each_word_index in range(length-each_input_length+1):
                        seq = split_line[each_word_index:each_word_index+each_input_length]
                        line = " ".join(seq)
                        training_sentences.append(line)  

            tokenizer = Tokenizer()
            tokenizer.fit_on_texts(training_sentences)

            sequences = np.array(tokenizer.texts_to_sequences(training_sentences))

            vocab_size = len(tokenizer.word_index) + 1
            X,y = sequences[:, :-1], sequences[:, -1]
            y = to_categorical(y, num_classes = vocab_size)

            for each_lstm_unit_num in lstm_unit_num:
                for each_dense_unit_num in dense_unit_num:
                    for each_dropout_rate in dropout_rate:
                
                        #model = training_with_parameters(X, y, vocab_size, each_input_length, each_lstm_unit_num, each_dropout_rate, each_dense_unit_num, epo)
                        name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(each_lstm_unit_num, each_dropout_rate, each_dense_unit_num,epo,each_input_length)
    

                        # Define our language model:
                        model = Sequential()
                        model.add(Embedding(vocab_size, 256))
                        model.add(LSTM(each_lstm_unit_num))
                        model.add(Dropout(each_dropout_rate))
                        model.add(Dense(each_dense_unit_num, activation='relu'))
                        model.add(Dense(vocab_size, activation='softmax'))
                        full_path = "/content/drive/MyDrive/parameters/"+name

                        model.summary()
                        model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

                        
                        print("%s cache saved"%(full_path))
                        checkpoint = ModelCheckpoint(full_path, 
                                                    monitor='loss', 
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min')
                        callbacks_list = [checkpoint]
                        model.fit(X,y, batch_size=256, epochs=epo, callbacks=callbacks_list)
                        
                        model.save_weights(full_path)
                        model_collection.append([model, each_input_length, each_lstm_unit_num, each_dropout_rate, each_dense_unit_num, epo])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 256)         4656128
# _________________________________________________________________
# lstm (LSTM)                  (None, 512)               1574912
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dense_1 (Dense)              (None, 18188)             4674316
# =================================================================
# Total params: 11,036,684
# Trainable params: 11,036,684
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5 cache saved
# Epoch 1/30
# 235/235 [==============================] - 30s 56ms/step - loss: 8.1383 - accuracy: 0.0420
#
# Epoch 00001: loss improved from inf to 7.75302, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 2/30
# 235/235 [==============================] - 14s 58ms/step - loss: 7.2371 - accuracy: 0.0601
#
# Epoch 00002: loss improved from 7.75302 to 7.20015, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 3/30
# 235/235 [==============================] - 14s 57ms/step - loss: 6.9066 - accuracy: 0.0808
#
# Epoch 00003: loss improved from 7.20015 to 6.90174, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 4/30
# 235/235 [==============================] - 14s 58ms/step - loss: 6.6198 - accuracy: 0.0967
#
# Epoch 00004: loss improved from 6.90174 to 6.64116, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 5/30
# 235/235 [==============================] - 13s 57ms/step - loss: 6.4130 - accuracy: 0.1102
#
# Epoch 00005: loss improved from 6.64116 to 6.43600, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 6/30
# 235/235 [==============================] - 14s 58ms/step - loss: 6.2100 - accuracy: 0.1195
#
# Epoch 00006: loss improved from 6.43600 to 6.24416, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 7/30
# 235/235 [==============================] - 14s 58ms/step - loss: 6.0075 - accuracy: 0.1290
#
# Epoch 00007: loss improved from 6.24416 to 6.03369, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 8/30
# 235/235 [==============================] - 13s 56ms/step - loss: 5.8185 - accuracy: 0.1366
#
# Epoch 00008: loss improved from 6.03369 to 5.84780, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 9/30
# 235/235 [==============================] - 13s 57ms/step - loss: 5.6343 - accuracy: 0.1426
#
# Epoch 00009: loss improved from 5.84780 to 5.66482, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 10/30
# 235/235 [==============================] - 14s 58ms/step - loss: 5.4089 - accuracy: 0.1512
#
# Epoch 00010: loss improved from 5.66482 to 5.47567, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 11/30
# 235/235 [==============================] - 13s 57ms/step - loss: 5.2362 - accuracy: 0.1581
#
# Epoch 00011: loss improved from 5.47567 to 5.27530, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 12/30
# 235/235 [==============================] - 13s 57ms/step - loss: 4.9728 - accuracy: 0.1698
#
# Epoch 00012: loss improved from 5.27530 to 5.06825, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 13/30
# 235/235 [==============================] - 14s 58ms/step - loss: 4.7962 - accuracy: 0.1752
#
# Epoch 00013: loss improved from 5.06825 to 4.85029, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 14/30
# 235/235 [==============================] - 13s 56ms/step - loss: 4.5660 - accuracy: 0.1901
#
# Epoch 00014: loss improved from 4.85029 to 4.62825, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 15/30
# 235/235 [==============================] - 13s 57ms/step - loss: 4.3467 - accuracy: 0.2082
#
# Epoch 00015: loss improved from 4.62825 to 4.41316, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 16/30
# 235/235 [==============================] - 13s 57ms/step - loss: 4.1243 - accuracy: 0.2297
#
# Epoch 00016: loss improved from 4.41316 to 4.20596, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 17/30
# 235/235 [==============================] - 13s 56ms/step - loss: 3.9179 - accuracy: 0.2542
#
# Epoch 00017: loss improved from 4.20596 to 4.00146, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 18/30
# 235/235 [==============================] - 13s 57ms/step - loss: 3.7096 - accuracy: 0.2765
#
# Epoch 00018: loss improved from 4.00146 to 3.80414, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 19/30
# 235/235 [==============================] - 13s 57ms/step - loss: 3.5440 - accuracy: 0.3018
#
# Epoch 00019: loss improved from 3.80414 to 3.61867, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 20/30
# 235/235 [==============================] - 13s 56ms/step - loss: 3.3765 - accuracy: 0.3217
#
# Epoch 00020: loss improved from 3.61867 to 3.45492, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 21/30
# 235/235 [==============================] - 13s 57ms/step - loss: 3.1906 - accuracy: 0.3494
#
# Epoch 00021: loss improved from 3.45492 to 3.29420, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 22/30
# 235/235 [==============================] - 13s 57ms/step - loss: 3.0542 - accuracy: 0.3687
#
# Epoch 00022: loss improved from 3.29420 to 3.13630, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 23/30
# 235/235 [==============================] - 13s 56ms/step - loss: 2.9002 - accuracy: 0.3932
#
# Epoch 00023: loss improved from 3.13630 to 2.98671, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 24/30
# 235/235 [==============================] - 13s 57ms/step - loss: 2.7486 - accuracy: 0.4205
#
# Epoch 00024: loss improved from 2.98671 to 2.84481, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 25/30
# 235/235 [==============================] - 13s 55ms/step - loss: 2.6310 - accuracy: 0.4392
#
# Epoch 00025: loss improved from 2.84481 to 2.70793, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 26/30
# 235/235 [==============================] - 13s 54ms/step - loss: 2.4945 - accuracy: 0.4621
#
# Epoch 00026: loss improved from 2.70793 to 2.59286, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 27/30
# 235/235 [==============================] - 13s 55ms/step - loss: 2.3924 - accuracy: 0.4791
#
# Epoch 00027: loss improved from 2.59286 to 2.46910, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 28/30
# 235/235 [==============================] - 13s 57ms/step - loss: 2.2633 - accuracy: 0.4996
#
# Epoch 00028: loss improved from 2.46910 to 2.35479, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 29/30
# 235/235 [==============================] - 13s 57ms/step - loss: 2.1508 - accuracy: 0.5228
#
# Epoch 00029: loss improved from 2.35479 to 2.24974, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Epoch 30/30
# 235/235 [==============================] - 13s 57ms/step - loss: 2.0745 - accuracy: 0.5322
#
# Epoch 00030: loss improved from 2.24974 to 2.14149, saving model to /content/drive/MyDrive/parameters/rnn_weights_512_0.20_256_30_20.h5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1024)              5246976
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_3 (Dense)              (None, 18188)             4674316
# =================================================================
# Total params: 14,839,820
# Trainable params: 14,839,820
# Non-trainable params: 0
# _________________________________________________________________
# /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5 cache saved
# Epoch 1/30
# 235/235 [==============================] - 19s 73ms/step - loss: 8.0905 - accuracy: 0.0427
#
# Epoch 00001: loss improved from inf to 7.73266, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 2/30
# 235/235 [==============================] - 17s 74ms/step - loss: 7.1980 - accuracy: 0.0639
#
# Epoch 00002: loss improved from 7.73266 to 7.20541, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 3/30
# 235/235 [==============================] - 17s 74ms/step - loss: 6.9552 - accuracy: 0.0823
#
# Epoch 00003: loss improved from 7.20541 to 6.94344, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 4/30
# 235/235 [==============================] - 17s 74ms/step - loss: 6.6787 - accuracy: 0.0958
#
# Epoch 00004: loss improved from 6.94344 to 6.76947, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 5/30
# 235/235 [==============================] - 17s 74ms/step - loss: 6.5552 - accuracy: 0.1009
#
# Epoch 00005: loss improved from 6.76947 to 6.56025, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 6/30
# 235/235 [==============================] - 17s 74ms/step - loss: 6.3031 - accuracy: 0.1099
#
# Epoch 00006: loss improved from 6.56025 to 6.33524, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 7/30
# 235/235 [==============================] - 17s 74ms/step - loss: 6.2392 - accuracy: 0.1207
#
# Epoch 00007: loss improved from 6.33524 to 6.29111, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 8/30
# 235/235 [==============================] - 17s 73ms/step - loss: 6.0567 - accuracy: 0.1277
#
# Epoch 00008: loss improved from 6.29111 to 6.08591, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 9/30
# 235/235 [==============================] - 17s 73ms/step - loss: 5.8384 - accuracy: 0.1342
#
# Epoch 00009: loss improved from 6.08591 to 5.88411, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 10/30
# 235/235 [==============================] - 17s 73ms/step - loss: 5.6182 - accuracy: 0.1422
#
# Epoch 00010: loss improved from 5.88411 to 5.66733, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 11/30
# 235/235 [==============================] - 17s 73ms/step - loss: 5.3984 - accuracy: 0.1488
#
# Epoch 00011: loss improved from 5.66733 to 5.44995, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 12/30
# 235/235 [==============================] - 17s 73ms/step - loss: 5.1621 - accuracy: 0.1553
#
# Epoch 00012: loss improved from 5.44995 to 5.21979, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 13/30
# 235/235 [==============================] - 17s 74ms/step - loss: 4.9221 - accuracy: 0.1653
#
# Epoch 00013: loss improved from 5.21979 to 4.97771, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 14/30
# 235/235 [==============================] - 17s 74ms/step - loss: 4.6695 - accuracy: 0.1797
#
# Epoch 00014: loss improved from 4.97771 to 4.72063, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 15/30
# 235/235 [==============================] - 17s 73ms/step - loss: 4.3615 - accuracy: 0.2073
#
# Epoch 00015: loss improved from 4.72063 to 4.44910, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 16/30
# 235/235 [==============================] - 17s 74ms/step - loss: 4.0953 - accuracy: 0.2311
#
# Epoch 00016: loss improved from 4.44910 to 4.17854, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 17/30
# 235/235 [==============================] - 17s 74ms/step - loss: 3.8185 - accuracy: 0.2625
#
# Epoch 00017: loss improved from 4.17854 to 3.90715, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 18/30
# 235/235 [==============================] - 17s 72ms/step - loss: 3.5444 - accuracy: 0.2964
#
# Epoch 00018: loss improved from 3.90715 to 3.64894, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 19/30
# 235/235 [==============================] - 17s 73ms/step - loss: 3.2823 - accuracy: 0.3337
#
# Epoch 00019: loss improved from 3.64894 to 3.38810, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 20/30
# 235/235 [==============================] - 17s 73ms/step - loss: 3.0534 - accuracy: 0.3685
#
# Epoch 00020: loss improved from 3.38810 to 3.15218, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 21/30
# 235/235 [==============================] - 17s 73ms/step - loss: 2.8224 - accuracy: 0.4074
#
# Epoch 00021: loss improved from 3.15218 to 2.91444, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 22/30
# 235/235 [==============================] - 17s 73ms/step - loss: 2.5729 - accuracy: 0.4478
#
# Epoch 00022: loss improved from 2.91444 to 2.68369, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 23/30
# 235/235 [==============================] - 17s 73ms/step - loss: 2.3685 - accuracy: 0.4861
#
# Epoch 00023: loss improved from 2.68369 to 2.46200, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 24/30
# 235/235 [==============================] - 17s 73ms/step - loss: 2.1437 - accuracy: 0.5244
#
# Epoch 00024: loss improved from 2.46200 to 2.24633, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 25/30
# 235/235 [==============================] - 17s 73ms/step - loss: 1.9696 - accuracy: 0.5577
#
# Epoch 00025: loss improved from 2.24633 to 2.03522, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 26/30
# 235/235 [==============================] - 17s 74ms/step - loss: 1.7654 - accuracy: 0.5965
#
# Epoch 00026: loss improved from 2.03522 to 1.83537, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 27/30
# 235/235 [==============================] - 17s 73ms/step - loss: 1.5620 - accuracy: 0.6378
#
# Epoch 00027: loss improved from 1.83537 to 1.64783, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 28/30
# 235/235 [==============================] - 17s 73ms/step - loss: 1.3839 - accuracy: 0.6747
#
# Epoch 00028: loss improved from 1.64783 to 1.46682, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 29/30
# 235/235 [==============================] - 17s 73ms/step - loss: 1.2381 - accuracy: 0.7073
#
# Epoch 00029: loss improved from 1.46682 to 1.29697, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5
# Epoch 30/30
# 235/235 [==============================] - 17s 72ms/step - loss: 1.0715 - accuracy: 0.7433
#
# Epoch 00030: loss improved from 1.29697 to 1.14052, saving model to /content/drive/MyDrive/parameters/rnn_weights_1024_0.20_256_30_20.h5

# %%
# !python -m spacy download en_core_web_lg
# !pip3 install -U spacy
import spacy
from tensorflow.keras.preprocessing.sequence import pad_sequences
from spacy.lang.en.examples import sentences
# Out:
# 2021-04-05 20:21:41.740147: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8MB)
#      |████████████████████████████████| 778.8MB 23kB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.0.0) (3.0.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (20.9)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.7.3)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.8.1)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.7.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.41.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (54.2.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.19.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.4.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.4)
# Installing collected packages: en-core-web-lg
#   Found existing installation: en-core-web-lg 2.2.5
#     Uninstalling en-core-web-lg-2.2.5:
#       Successfully uninstalled en-core-web-lg-2.2.5
# Successfully installed en-core-web-lg-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# Requirement already up-to-date: spacy in /usr/local/lib/python3.7/dist-packages (3.0.5)
# Requirement already satisfied, skipping upgrade: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.3.2)
# Requirement already satisfied, skipping upgrade: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy) (3.8.1)
# Requirement already satisfied, skipping upgrade: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.0)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (54.2.0)
# Requirement already satisfied, skipping upgrade: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied, skipping upgrade: thinc<8.1.0,>=8.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.2)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied, skipping upgrade: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.7.3)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.5)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.0)
# Requirement already satisfied, skipping upgrade: typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from spacy) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (20.9)
# Requirement already satisfied, skipping upgrade: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy) (3.4.1)
# Requirement already satisfied, skipping upgrade: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (3.0.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (2.4.7)

# %%
nlp = spacy.load('en_core_web_lg')

# %%
file = open("/content/drive/MyDrive/466data/en_tech_test.txt", "rb")
test_set = file.read().decode(encoding='utf-8')
file = open("/content/drive/MyDrive/466data/en_tech_validate.txt", "rb")
validate_set = file.read().decode(encoding='utf-8')
processed_test_set = test_set.split("\n")
processed_validate_set = validate_set.split("\n")

# %%
def predict_single(model, tokenizer, seed_text,maxlength):
    
    predicted_word = None
    encoded = tokenizer.texts_to_sequences([seed_text])[0]
    encoded = pad_sequences([encoded], maxlen = maxlength-1, truncating='pre')

    temp = model.predict(encoded)

    y_predict = np.argmax(temp, axis=-1)

    for word, index in tokenizer.word_index.items():
        if index == y_predict:
            predicted_word = word
            break
    return str(predicted_word)

def validate(validate_sentences, nlp, model,tokenizer,input_size):
  new = []
  for i in range(len(validate_sentences)):
      new.append(validate_sentences[i].split())
  validate_sequences = np.array(new)
  validate_X, validate_y = validate_sequences[:, :-1], validate_sequences[:, -1]
  average_accuracy = 0
  num = 0
  for i in range(len(validate_X)):
      if i%200==0:
          print(i)
      prediction = predict_single(model, tokenizer, ' '.join(validate_X[i]),input_size)
      x = nlp(prediction)
      y = nlp(str(validate_y[i]))

      if (x[0].has_vector) and (y[0].has_vector):
          average_accuracy += nlp(prediction).similarity(nlp(str(validate_y[i])))
          num += 1

  average_accuracy /= num
  return average_accuracy

# %%
input_length = [5, 20]
lstm_unit_num = [256, 512, 1024]
dense_unit_num = 256
dropout_rate = 0.2
epoch = 30
model_list = []
tokenizer = None
for i in lstm_unit_num:
    for j in input_length:
        vocab_size,tokenizer = get_vocab_size(processed_train_set,j)  
        #vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch   
        model = load_weights_to_model(vocab_size, j, i, dropout_rate, dense_unit_num, epoch)
        

        # validation
        validate_sentences = []
        input_size = j
        for line in processed_validate_set:
            temp = line.split()
            for index in range(input_size, len(temp)):
                seq = temp[index - input_size:index]
                temp2 = " ".join(seq)
                validate_sentences.append(temp2)
        
        accuracy = validate(validate_sentences, nlp, model,tokenizer,j)
        print("LSTM %d, Input_length %d finished, accuracy %.3f"%(i,j,accuracy))
        model_list.append([model,vocab_size, j, i, dropout_rate, dense_unit_num, epoch, accuracy])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 256)         5668352
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 22142)             5690494
# =================================================================
# Total params: 11,949,950
# Trainable params: 11,949,950
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# LSTM 256, Input_length 5 finished, accuracy 0.503
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_7 (Dense)              (None, 18188)             4674316
# =================================================================
# Total params: 9,921,548
# Trainable params: 9,921,548
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# LSTM 256, Input_length 20 finished, accuracy 0.432
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 256)         5668352
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 512)               1574912
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_9 (Dense)              (None, 22142)             5690494
# =================================================================
# Total params: 13,065,086
# Trainable params: 13,065,086
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# LSTM 512, Input_length 5 finished, accuracy 0.511
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 512)               1574912
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_11 (Dense)             (None, 18188)             4674316
# =================================================================
# Total params: 11,036,684
# Trainable params: 11,036,684
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# LSTM 512, Input_length 20 finished, accuracy 0.428
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_6 (Embedding)      (None, None, 256)         5668352
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 1024)              5246976
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_13 (Dense)             (None, 22142)             5690494
# =================================================================
# Total params: 16,868,222
# Trainable params: 16,868,222
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# LSTM 1024, Input_length 5 finished, accuracy 0.523
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, None, 256)         4656128
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 1024)              5246976
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_15 (Dense)             (None, 18188)             4674316
# =================================================================
# Total params: 14,839,820
# Trainable params: 14,839,820
# Non-trainable params: 0
# _________________________________________________________________
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# LSTM 1024, Input_length 20 finished, accuracy 0.443

# %%
max_value = 0
max_index = 0
for i in range(len(model_list)):
    if model_list[i][-1]>max_value:
        max_value = model_list[i][-1]
        max_index = model_list[i]

# %%
import matplotlib.pyplot as plt

# %%
#vocab_size, each_input_length, lstm_unit_num, dropout_rate, dense_unit_num, epoch   
for k in [256,512,1024]:
    temp_list = [(i[2],i[-1]) for i in model_list if i[3] == k]
    plt.plot([i[0] for i in temp_list],[i[1] for i in temp_list],'o-',label="LSTM unit=%d"%k)
    #plt.legend(str(k))
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.plot(max_index[2], max_index[-1], 'r*',markersize=10)

# %%
model = load_weights_to_model(22142, 5, 1024, dropout_rate, dense_unit_num, epoch)

#name = "rnn_weights_%d_%.2f_%d_%d_%d.h5"%(each_lstm_unit_num, each_dropout_rate, each_dense_unit_num,epo,each_input_length)
accuracy_list = []
for input_size in [2,3,5,10,20]:
    test_sentences = []
    for line in processed_test_set:
        #print("line",line)
        temp = line.split(' ')
        #print("temp",temp)
        if input_size<=len(temp):
            for i in range(input_size, len(temp)):
                #print("i",i)
                #print("input_size",input_size)
                seq = temp[i - input_size:i]
                #print("sep",seq)
                temp2 = " ".join(seq)
                test_sentences.append(temp2)
                #print("test",test_sentences)
                #assert 1==2,'stop'
    #print(test_sentences[0:20])
    #print(len(test_sentences))
    new = []
    
    #print(len(test_sentences))
    for i in range(len(test_sentences)):
        if i%5==0:
            
            new.append(test_sentences[i].split())
    print("new",new[0:2])
    print(new[0][0])
    test_seq = new

    test_X, test_y = [i[0:-1] for i in test_seq], [i[-1] for i in test_seq]
    print(test_X[0:10])
    print(test_seq[:][1])
    average_accuracy = 0
    num = 0
    for i in range(len(test_X)):
        prediction = predict_single(model, tokenizer, ' '.join(test_X[i]),input_size)
        if i%200==0:
            print(i)
        x = nlp(prediction)
        y = nlp(str(test_y[i]))

        if (x[0].has_vector) and (y[0].has_vector):
            average_accuracy += nlp(prediction).similarity(nlp(str(test_y[i])))
            num += 1  
    average_accuracy /= num
    accuracy_list.append((input_size,average_accuracy))
print(accuracy_list)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_8 (Embedding)      (None, None, 256)         5668352
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 1024)              5246976
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 256)               262400
# _________________________________________________________________
# dense_17 (Dense)             (None, 22142)             5690494
# =================================================================
# Total params: 16,868,222
# Trainable params: 16,868,222
# Non-trainable params: 0
# _________________________________________________________________
# new [['merle', 'kilgore'], ['country', 'hit']]
# merle
# [['merle'], ['country'], ['has'], ['failure'], ['a'], ['that'], ['money'], ['on'], ['nbc'], ['had']]
# ['country', 'hit']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# new [['merle', 'kilgore', 'cowriter'], ['country', 'hit', 'ring']]
# merle
# [['merle', 'kilgore'], ['country', 'hit'], ['has', 'died'], ['other', 'scam'], ['link', 'to'], ['supposedly', 'let'], ['but', 'instead'], ['their', 'computers'], ['that', 'boxing'], ['violated', 'but']]
# ['country', 'hit', 'ring']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# new [['merle', 'kilgore', 'cowriter', 'of', 'the'], ['country', 'hit', 'ring', 'of', 'fire']]
# merle
# [['merle', 'kilgore', 'cowriter', 'of'], ['country', 'hit', 'ring', 'of'], ['has', 'died', 'of', 'congestive'], ['emails', 'included', 'a', 'link'], ['a', 'website', 'that', 'supposedly'], ['people', 'donate', 'money', 'but'], ['loaded', 'spyware', 'on', 'their'], ['alleged', 'that', 'boxing', 'regulations'], ['been', 'violated', 'but', 'failed'], ['their', 'attempt', 'to', 'have']]
# ['country', 'hit', 'ring', 'of', 'fire']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# new [['merle', 'kilgore', 'cowriter', 'of', 'the', 'country', 'hit', 'ring', 'of', 'fire'], ['country', 'hit', 'ring', 'of', 'fire', 'has', 'died', 'of', 'congestive', 'heart']]
# merle
# [['merle', 'kilgore', 'cowriter', 'of', 'the', 'country', 'hit', 'ring', 'of'], ['country', 'hit', 'ring', 'of', 'fire', 'has', 'died', 'of', 'congestive'], ['emails', 'included', 'a', 'link', 'to', 'a', 'website', 'that', 'supposedly'], ['a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but'], ['people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their'], ['alleged', 'that', 'boxing', 'regulations', 'had', 'been', 'violated', 'but', 'failed'], ['been', 'violated', 'but', 'failed', 'in', 'their', 'attempt', 'to', 'have'], ['a', 'village', 'says', 'prof', 'reddy', 'i', 'know', 'what', 'the'], ['i', 'know', 'what', 'the', 'population', 'is', 'like', 'many', 'of'], ['is', 'like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many']]
# ['country', 'hit', 'ring', 'of', 'fire', 'has', 'died', 'of', 'congestive', 'heart']
# 0
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# new [['other', 'scam', 'emails', 'included', 'a', 'link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on'], ['link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their', 'computers', 'that', 'grabbed', 'confidential']]
# other
# [['other', 'scam', 'emails', 'included', 'a', 'link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware'], ['link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their', 'computers', 'that', 'grabbed'], ['village', 'says', 'prof', 'reddy', 'i', 'know', 'what', 'the', 'population', 'is', 'like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many', 'of'], ['know', 'what', 'the', 'population', 'is', 'like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many', 'of', 'them', 'have', 'other', 'concerns', 'there'], ['like', 'many', 'of', 'them', 'are', 'illiterate', 'and', 'many', 'of', 'them', 'have', 'other', 'concerns', 'there', 'nobody', 'will', 'use', 'it', 'for'], ['illiterate', 'and', 'many', 'of', 'them', 'have', 'other', 'concerns', 'there', 'nobody', 'will', 'use', 'it', 'for', 'the', 'conventional', 'uses', 'of', 'a'], ['have', 'other', 'concerns', 'there', 'nobody', 'will', 'use', 'it', 'for', 'the', 'conventional', 'uses', 'of', 'a', 'pc', 'word', 'processing', 'and', 'powerpoint'], ['in', 'a', 'statement', 'google', 'said', 'the', 'feature', 'was', 'still', 'only', 'in', 'beta', 'ie', 'trial', 'stage', 'and', 'that', 'the', 'company'], ['they', 'are', 'likely', 'to', 'have', 'higher', 'disposable', 'incomes', 'and', 'can', 'afford', 'the', 'price', 'of', 'bigscreen', 'highdefinition', 'display', 'technologies', 'and'], ['recent', 'years', 'she', 'appeared', 'in', 'bbc', 'miniseries', 'the', 'cazalets', 'and', 'played', 'mrs', 'potts', 'in', 'the', 'london', 'stage', 'version', 'of']]
# ['link', 'to', 'a', 'website', 'that', 'supposedly', 'let', 'people', 'donate', 'money', 'but', 'instead', 'loaded', 'spyware', 'on', 'their', 'computers', 'that', 'grabbed', 'confidential']
# 0
# 200
# 400
# 600
# 800
# 1000
# [(2, 0.3529455827792085), (3, 0.36202651499498395), (5, 0.32006224357531093), (10, 0.30598722793168864), (20, 0.3043680919838556)]

# %%
x = [i[0]-1 for i in accuracy_list]
y = [i[1] for i in accuracy_list]
plt.plot(x,y,'o-')
plt.title("RNN-LSTM with epoch=30")
plt.xlabel("test sentense word length")
plt.ylabel("average similarity")
# Out:
# Text(0, 0.5, 'average similarity')
